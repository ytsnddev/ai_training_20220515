# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd ./../drive/MyDrive/'Colab Notebooks'
# !git clone https://github.com/ytsnddev/ai_training_20220515.git
# %cd ai_training_20220515

# !git config --global user.email "yuuta.sonoda@gmail.com"
# !git config --global user.name "ytsnddev"
# !git config --global user.password "Danc1ng924"

# !git remote set-url origin https://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@github.com/ytsnddev/ai_training_20220515.git
# Out:
# Cloning into 'ai_training_20220515'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 7 (delta 0), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (7/7), done.
# /content/drive/MyDrive/Colab Notebooks/ai_training_20220515

# %% [markdown]
# # Google Colab
#
# ## Google Colab
#
#
# ## Google Colabへのアクセス
#
# ![Google Colabスクリーン](notebooks/image/google_colab_screen.png)
